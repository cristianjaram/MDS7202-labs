# %% [markdown]
# **MDS7202: Laboratorio de Programación Científica para Ciencia de Datos**
#
# ### 👨‍🏫👩‍🏫 Cuerpo Docente:
# - Profesores: Diego Cortez, Gabriel Iturra
# - Auxiliares: Melanie Peña, Valentina Rojas
# - Ayudantes: Nicolás Cabello, Cristopher Urbina
#
# ### 👨‍💻👩‍💻 Estudiantes:
# - Estudiante n°1: Cristian Jara
# - Estudiante n°2: Ferlipe Fierro
#
# _Por favor, lean detalladamente las instrucciones de la tarea antes de empezar a escribir._
#
# ---
#
# [https://github.com/cristianjaram/MDS7202-labs.git](https://github.com/cristianjaram/MDS7202-labs.git)

# %% [markdown]
# ## 📚 Reglas

# %% [markdown]
# El proyecto consta de **dos entregas parciales** y una **entrega final** en donde la primera entrega la idea es poder reflejar lo aprendido durante la primera mitad del curso, que será sobre los contenidos relacionados a *machine learning*, la segunda será sobre los contenidos de la segunda mitad del curso relacionados a *MLOps* y por último la entrega final constará de dos partes, donde la primera será relacionada con experimentación sobre nuevos datasets que serán disponibilizados durante las últimas semanas del curso de manera incremental y una segunda parte que será el informe final escrito que deberá explicar el desarrollo del proyecto completo, como tambien los resultados y análisis de los experimentos realizados sobre los datasets incrementales. La idea es que todo el código esté desarrollado durante las primeras dos entregas y luego en la entrega final sólo se ejecute el código sobre nuevos conjuntos de datos.
#
# La idea de generar el proyecto por etapas es poder aliviar la carga de trabajo en las últimas semanas del semestre donde sabemos que están muy cargado con entregas, pruebas y exámenes de otros ramos, y así garantizamos que habiendo la desarrollado las dos primeras entregas parciales, tendrán el grueso del proyecto listo para luego experimentar y documentar.
#
# ---
# ### **Fechas de entrega**
# - **Entrega parcial 1**: 7 de octubre
# - **Entrega parcial 2**: 14 de noviembre
# - **Entrega final**: Por definir
#
# ---
#
# ### **Requisitos del proyecto**
# - **Grupos**: Formar equipos de **2 personas**. No se aceptarán trabajos individuales o grupos con más integrantes.
# - **Consultas**: Cualquier duda fuera del horario de clases debe ser planteada en el foro correspondiente. Los mensajes enviados al equipo docente serán respondidos únicamente por este medio. Por favor, revisen las respuestas anteriores en el foro antes de realizar nuevas consultas.
# - **Plagio**: La copia o reutilización no autorizada de trabajos de otros grupos está **estrictamente prohibida**. El incumplimiento de esta norma implicará la anulación inmediata del proyecto y una posible sanción académica.
# - **Material permitido**: Pueden usar cualquier material del curso, ya sea notas, lecturas, códigos, o referencias proporcionadas por los docentes, que consideren útil para el desarrollo del proyecto.
#
# ---
#
# ### **Entregables y etapas**
#
# #### **1. Entrega Parcial 1**
# - Dispondrán de los archivos de datos **productos.parquet**, **clientes.parquet** y **transacciones.parquet** para el modelamiento inicial.
# - Utilizarán estos archivos para desarrollar lo solicitado para la entrega 1.
# - En esta etapa, se espera que apliquen todos los conocimientos aprendidos durante la primera parte del curso relacionados con *machine learning*.
# - **Informe**: No se exige un avance del informe en esta etapa, sólo un notebook con su desarrollo actual, pero se **recomienda comenzar** a redactar el informe final en paralelo para disminuir la carga académica en las etapas posteriores.
#
# #### **2. Entrega Parcial 2**
# - En esta entrega, deberán aplicar los conocimientos aprendidos durante la segunda mitad del curso sobre *MLOps*
# - Se espera que implementen estos conocimientos para desplegar su modelo elegido en la primera entrega y crear *pipelines* automatizados que simulen un entorno productivo.
# - **Informe**: Similar a la primera etapa, no se exige un avance del informe, pero se **recomienda avanzar con su redacción** para evitar una acumulación de trabajo en la etapa final.
#
# #### **3. Entrega Final**
# - En la entrega final, deberán realizar dos etapas:
# 	- La primera etapa es sobre experimentación utilizando datasets incrementales que se irán disponibilizando de manera parcial, para que vayan generando predicciones con su modelo ya desplegado. El objetivo de esta etapa es poder testear su solución *end-to-end* y que vayan analizando los resultados obtenidos a medida que se van agregando más datos.
# 	- La segunda etapa consiste en redactar un informe final que deberá explicar el desarrollo completo de tu proyecto y un análisis profundo de sus resultados de experimentación. Este informe debera incluir a lo menos las siguientes secciones:
# 		- Análisis exploratorio de datos
# 		- Metodología aplicada
# 		- Selección y entrenamiento de modelos
# 		- Evaluación de resultados
# 		- Optimización de modelos
# 		- Interpretabilidad
# 		- Re-entrenamiento
# 		- Tracking con MLFlow
# 		- Creación de la aplicación web con Gradio y FastAPI
#
# Es **altamente recomendable** ir redactando el informe en paralelo al desarrollo de los modelos para garantizar que toda la información relevante quede documentada adecuadamente.
#
# ### Nota Final
#
# La calificación final de su proyecto se calculará utilizando la siguiente ponderación:
#
# $$Nota Final = 0.30 * EntregaParcial1 + 0.40 * EntregaParcial2 + 0.30 * EntregaFinal$$
#
# ---
#
# ### **Instrucciones importantes**
#
# 1. **Formato del informe**:
#    - El informe debe estar integrado dentro de un **Jupyter Notebook**. No es necesario subirlo a una plataforma externa, pero debe cumplir con los siguientes requisitos:
#      - Estructura clara y ordenada.
#      - Código acompañado de explicaciones detalladas.
#      - Resultados presentados de forma visual y analítica.
#
# 2. **Descuento por informes deficientes**:
#    - Cualquier sección del informe que no tenga una explicación adecuada o no respete el formato será penalizada con un descuento en la nota. Esto incluye código sin comentarios o análisis que no sean coherentes con los resultados presentados.
#    - **Comentarios sin formatear de ChatGPT o herramientas similares serán penalizados (e.g: "Inserta tu modelo acá", etc.)**

# %% [markdown]
# ## Notas adicionales
# - No necesitan tener un rendimiento cercano al 100% para tener una resolución exitosa en el proyecto.
# - Utilizar paralelización para acelerar búsquedas. Esto podría ser una buena solución para el caso de que la búsqueda de hiperparámetros sea muy lenta. En caso de tener problemas de RAM, reducir la cantidad de `jobs` a algo que su computador/interprete web pueda procesar.
# - Generar grillas de búsquedas razonables. Entre más grande es la grilla, más lento el proceso de búsqueda. Utilice grillas de tamaños adecuados para que la búsqueda converga en tiempos razonables y no se demore 3.5 eternidades en terminar.

# %% [markdown]
# # 📬 Entrega Parcial 2 (40% del Proyecto)

# %% [markdown]
# ### 📪 Fecha de Entrega: 14 de noviembre

# %% [markdown]
# ## 📖 Enunciado
#
# Gracias al impecable trabajo que presento su dupla, la primera etapa del proyecto fue un éxito rotundo! Pero no hay tiempo para descansar...

# %% [markdown]
# Tras haber entrenado su primer modelo predictivo, el equipo **Deep Drinkers 🤖** ha demostrado que tiene lo necesario para revolucionar la manera en que se toman decisiones comerciales dentro de **SodAI Drinks 🥤**. El comité de innovación ha quedado tan impresionado que les ha encomendado una nueva y más desafiante misión.
#
# En esta segunda fase del proyecto, deberán fortalecer su solución y prepararla para el mundo real (también conocido como producción). La idea es que tomen el modelo elegido en la primera entrega y lo utilicen para implementar toda esta segunda entrega que tendrá como objetivo último, disponibilizar su modelo en producción para que pueda ser consumido a través de la web. Entonces, deben aplicar lo aprendido en las clases relacionadas a `MLOps` (despliegue, `Docker`, *pipeline productivo*, monitoreo), en conjunto con los conocimientos adquiridos en la primera parte del curso (`Mlflow`, `SHAP`, `sklearn`, entre otros.) e implementarlo sobre su modelo.
#
# Esta nueva misión que se les ha encargado incluye que realicen, a lo menos, las siguientes partes.
#
# ⚠️ Advertencia importante: **SodAI Drinks** 🥤 no quiere tener que despedir a sus empleados estrella si su modelo empieza a hacer predicciones incoherentes.

# %% [markdown]
# ## 📌Pipelines Productivos [3.0 puntos]

# %% [markdown]
# En esta etapa, el equipo debe diseñar e implementar una canalización automatizada utilizando `Apache Airflow` para orquestar de forma eficiente todo el flujo de trabajo de su sistema predictivo, integrando herramientas como `MLflow`, `Optuna` y `SHAP`. Esta canalización debe contemplar el ciclo completo de modelado: desde la extracción de datos hasta la generación de predicciones y el seguimiento de resultados, de manera robusta y flexible.
#
# Aunque en esta entrega se trabajará únicamente con los datos iniciales proporcionados, es **fundamental** que el *pipeline* sea diseñado con visión de producción, tal como se esperaría en un entorno empresarial real. Por tanto, el *pipeline* debe estar preparado para detectar *drift* en los datos y, de ser necesario, reentrenar el modelo de forma automatizada ante la llegada de nuevos datos.
#
# **Nota importante: Tómense un tiempo para leer detenidamente esto para entender lo que esto significa. Para entrega final del proyecto se les pedirá que su pipeline reciba un nuevo conjunto de datos (por ejemplo, ustedes cuentan con datos (t) y reciben una nueva semana de datos (t+1)) y genere la predicción para la semana siguiente (t+2). <u>Repetiremos este ejercicio varias veces</u>. Tome esto en consideración para el desarrollo de esta sección.**
#
# **BONUS**: Si deciden utilizar `MLflow`, se les otorgará entre 0 y 0.5 puntos de puntaje adicional dependiendo su uso y en qué partes lo utilizan.
#
# Su *pipeline* debe considerar los siguientes puntos:
#
# - **Extracción de datos**: Configurar `Airflow` para obtener automáticamente los datos y prepararlos como se realizó en la primera entrega.
#   - Asuman que los nuevos datos cuentan con la misma estructura de `transacciones.parquet`.
#   - Para esta parte, pueden asumir que los datos aparecen *mágicamente* en su directorio de trabajo.
#   - Pueden realizar supuestos adicionales, pero estos deben quedar evidenciados de forma clara y fácil de distinguir para su posterior revisión.
# - **Limpieza y transformación**: Estandarizar y preparar los datos para su uso en el modelo. Esta etapa debe ser modular y replicable para nuevos datos.
# - **Detección de drift en los datos [BONUS: 0.3 puntos]**: Desarrollar un sistema o modelo que sea capaz de distinguir cuando exista *drift* en los datos.
# - **Reentrenamiento del modelo**: Implementar una rutina de reentrenamiento y trackeo de resultados. Además, esta etaba debe considerar:
#     - Si deciden implementar la detección de *drift*, este paso sólo debe ser ejecutado en caso de que exista drift en los datos. En caso contrario, deben desarrollar código para que el reentrenamiento sea ejecutado de forma periódica.
#     - Optimización de hiperparámetros.
#     - Entrenar modelo con los hiperparámetros seleccionados usando la data nueva.
#     - Trackeo de sus resultados, registrando de manera organizada la siguiente información (se recomienda muchísimo usar `MLflow`):
#       - Métricas de desempeño
#       - Hiperparámetros del modelo
#       - Gráficos de interpretabilidad.
#     - Exportar el modelo entrenado para su posterior uso (se recomienda usar `MLflow` para esto).
#
#     Esta lógica puede quedar implementada como tareas condicionales, *placeholders* o módulos configurables, que se activarán más adelante.
#
# - **Generación de predicciones**: Utilizar el mejor modelo disponible para realizar predicciones sobre los datos (en otras palabras, predecir para cada cliente-producto si el cliente comprará el producto la próxima semana).
#
# **IMPORTANTE**: Como "próxima semana" deben usar la **semana siguiente a la semana más reciente presente en los datos**. Por ejemplo, si sus datos contienen hasta la última semana del 2024, se le pide generar predicciones para la primera semana del 2025.
#
# Para esta sección se esperan los siguientes entregables:
#
# * **Código del DAG de Airflow [2.0 puntos]**:
#   * Archivos Python con la definición completa del `DAG` y todos sus operadores.
#   * Scripts auxiliares para las diferentes tareas, si lo estima necesario (transformación, entrenamiento, evaluación, interpretabilidad, entre otros).
#   * Configuración del entorno `Airflow` (requisitos, conexiones, variables, entre otros).
#   * Todo el código debe ser reproducible.
#
# * **Video de ejecución del pipeline [0.5 puntos]**
#   * Deben adjuntar un video mostrando la ejecución del pipeline de `Airflow` siendo ejecutado de principio a fin.
#   * El pipeline debe ser ejecutado considerando un nuevo conjunto de datos de entrada (pueden generarlo de forma aleatoria, extraer una semana cualquiera del dataset, etc).
#   * La ejecución del pipeline DEBE mostrar como los datos pasan por la etapa de reentrenamiento. Pueden desarrollar flujos condicionales  para esto.
#   * No es necesario que suban este video al repositorio ni a u-cursos. En su lugar, pueden subirlo a Youtube o alguna otra plataforma de su preferencia y enviarnos el link de acceso junto a su entrega.
#
# * **Documentación detallada en markdown [0.5 puntos]**:
#   * Una descripción clara del `DAG`, explicando la funcionalidad de cada tarea y cómo se relacionan entre sí.
#   * Diagrama de flujo del *pipeline* completo.
#   * Una representación visual del `DAG` en la interfaz de `Airflow`.
#   * Explicación de cómo se diseñó la lógica para integrar futuros datos, detectar *drift* y reentrenar el modelo.
#   * Todos estos puntos deben estar contenidos en un archivo markdown junto a la carpeta de esta sección.
#
# * **Los puntos anteriores deben estar contenidos de forma ordenada en una carpeta llamada `airflow`**
#
# 👀 **Hint**: *Se recomienda revisar la siguiente documentación de [MLFlow](https://mlflow.org/docs/latest/tracking/#quickstart) y [Airflow](https://airflow.apache.org/docs/apache-airflow/stable/tutorial/fundamentals.html) para el desarrollo de esta sección.*

# %% [markdown]
# ## 📌 Desarrollo de Aplicación Web [2.0 puntos]

# %% [markdown]
# Una vez implementado el *pipeline* productivo, el siguiente paso es desarrollar una interfaz que permita a los usuarios finales de **SodAI Drinks 🥤** interactuar con el modelo desplegado. Esta aplicación web debe consumir las predicciones generadas por el *pipeline* desarrollado en la sección anterior, estableciendo así un flujo completo desde el procesamiento de datos hasta la visualización de resultados.
#
# En esta etapa, deberán construir una aplicación web que integre un *frontend* desarrollado en `Gradio` y un *backend* con `FastAPI`, asegurando la comunicación efectiva entre ambos componentes y con el *pipeline* previamente implementado. Para garantizar la portabilidad y facilidad del despliegue en diferentes entornos, tanto el *backend* como el *frontend* deben ser dockerizados.
#
# Para esta sección se esperan los siguientes entregables:
#
# * **Backend con FastAPI [0.9 puntos]**:
#   * Crear rutas (*endpoints*) para recibir solicitudes y devolver predicciones.
#   * Cargar el modelo entrenado. En caso de haber utilizado `MLFlow`, se les recomienda usarlo para cargar el modelo directamente.
#   * Procesar los datos que recibe la aplicación.
#   * Dockerfile para levantar contenedor.
#   * Todo su desarrollo debe estar contenido en una carpeta `backend`
#
# * **Frontend con Gradio [0.9 puntos]**:
#   * Crear una interfaz amigable donde los usuarios puedan introducir los datos.
#   * Mostrar los resultados de las predicciones de forma clara.
#   * Incluir explicaciones sobre cómo usar la aplicación (esto debe estar en la interfaz).
#   * Dockerfile para levantar contenedor.
#   * Todo su desarrollo debe estar contenido en una carpeta `frontend`
#
# * **Un archivo `docker-compose.yml` que permita ejecutar ambos contenedores juntos. [0.2 puntos]**
#
# * **Los puntos anteriores deben estar contenidos de forma ordenada en una carpeta llamada `app`.**
#
# * **Importante: Se revisará esta sección levantando la aplicación que entreguen mediante Docker. Naturalmente, si la aplicación tiene problemas en levantar se les descontará puntaje.**
#
# 👀 **Hint**: *Se recomienda revisar el cheatsheet de [Dockerlabs](https://dockerlabs.collabnix.com/docker/cheatsheet/) para optimizar la creación de las imágenes y contenedores.*

# %% [markdown]
# ## 📌Conclusiones  [1.0 punto]

# %% [markdown]
# En esta sección deben reflexionar sobre los aprendizajes, desafíos y oportunidades del enfoque `MLOps` aplicado. Sus reflexiones deben ser escritas en un archivo `conclusiones.md`
#
# Algunas ideas que pueden abordar:
# - ¿Cómo mejoró el desarrollo del proyecto al utilizar herramientas de *tracking* y despliegue?
# - ¿Qué aspectos del despliegue con `Gradio/FastAPI` fueron más desafiantes o interesantes?
# - ¿Cómo aporta `Airflow` a la robustez y escalabilidad del pipeline?
# - ¿Qué se podría mejorar en una versión futura del flujo? ¿Qué partes automatizarían más, qué monitorearían o qué métricas agregarían?

# %% [markdown]
# ## 🎁 Bonus [1.0 puntos]
#
# De forma adicional a todo el desarrollo anterior, pueden optar a obtener puntaje adicional desarrollando los siguientes puntos:
#
# * **Sistema de Recomendación [0.5 puntos]**:
#     * Debe generar 5 recomendaciones de productos para cualquier cliente.
#     * Debe entregar su solución separando backend y frontend, ambos dockerizados y comunicándose.
#     * Todo su desarrollo debe estar contenido en la carpeta `recsys`
#
# * **Chatbot Conversacional [0.5 puntos]**:
#     * Debe ser capaz de responder dudas sobre los datos existentes, por ejemplo:
#         * ¿Cuántos clientes únicos hay en el dataset?
#         * ¿Cuántas transacciones ha realizado el cliente X?
#         * ¿Cuántos productos únicos se encuentran en los datos?
#     * Debe entregar su solución separando backend y frontend, ambos dockerizados y comunicándose.
#     * Todo su desarrollo debe estar contenido en la carpeta `llm`

# %% [markdown]
# ## 📁 Estructura de entrega
#
# Se espera que su entrega cuente con la siguiente estructura de carpetas:
#
# ```bash
# entrega_2/
# │
# ├── airflow/ # Carpeta con todos los scripts de la sección Pipelines Productivos
# │
# ├── app/
# │ ├── backend/ # Carpeta con scripts del backend
# │ ├── frontend/ # Carpeta con scripts del frontend
# │ └── docker-compose.yml
# │
# ├── bonus/
# │ ├── recsys/ # Carpeta con scripts del bonus de Sistemas de Recomendación
# │ └── llm/ # Carpeta con scripts del bonus de Chat Conversacional
# │
# └── conclusiones.md # Conclusiones del trabajo realizado
# ```

# %% [markdown]
# Mucho éxito!

# %% [markdown]
# ---
#
# ## Desarrollo del Proyecto
#
# ### Configuración Inicial e Imports

# %% [markdown]
# Primero, optimizaremos en este notebook el modelo lightgbm de la entrega 1, y usaremos cross validation.

# %%
import sys
import warnings
import pandas as pd
import numpy as np

sys.path.append('.')
from src.data_processing import (
    load_data, build_dataset, temporal_split, prepare_features,
    calculate_iqr_limits, remove_outliers, get_feature_columns
)
from src.model import (
    create_model_pipeline, optimize_hyperparameters, train_final_model,
    evaluate_model, cross_validate_model, find_optimal_threshold,
    save_model, get_default_params
)
from src.prediction import (
    prepare_prediction_data, generate_predictions, summarize_predictions,
    save_predictions, get_next_week_date
)

warnings.filterwarnings('ignore')
pd.set_option('display.max_columns', None)

SEED = 42
np.random.seed(SEED)

# %%
DATA_PATH = '../entrega1'

clientes, productos, transacciones = load_data(DATA_PATH)
print(f"Clientes: {len(clientes)}, Productos: {len(productos)}, Transacciones: {len(transacciones)}")

df = build_dataset(DATA_PATH)
print(f"Dataset construido: {df.shape}")
print(f"Rango de fechas: {df['purchase_date'].min()} - {df['purchase_date'].max()}")
print(f"Distribución target: {df['target'].value_counts(normalize=True).to_dict()}")
# Out:
# Clientes: 1569, Productos: 971, Transacciones: 254936
# Dataset construido: (1617242, 17)
# Rango de fechas: 2024-01-07 00:00:00 - 2025-01-05 00:00:00
# Distribución target: {0: 0.8723382153072947, 1: 0.12766178469270523}

# %%
train, valid, test = temporal_split(df, train_end="2024-09-30", valid_end="2024-11-30")
print(f"Train: {len(train)}, Valid: {len(valid)}, Test: {len(test)}")

num_cols_outliers = ['X', 'Y', 'size']
iqr_limits = calculate_iqr_limits(train, num_cols_outliers)

train_clean = remove_outliers(train, iqr_limits)
valid_clean = remove_outliers(valid, iqr_limits)
test_clean = remove_outliers(test, iqr_limits)

X_train, y_train = prepare_features(train_clean)
X_valid, y_valid = prepare_features(valid_clean)
X_test, y_test = prepare_features(test_clean)

print(f"Train limpio: {X_train.shape}, Valid limpio: {X_valid.shape}, Test limpio: {X_test.shape}")

numeric_features, categorical_features = get_feature_columns()
print(f"Features numéricas: {numeric_features}")
print(f"Features categóricas: {categorical_features}")
# Out:
# Train: 1190046, Valid: 244112, Test: 183084
# Train limpio: (734721, 13), Valid limpio: (150712, 13), Test limpio: (113034, 13)
# Features numéricas: ['promedio_items_t-1', 'promedio_items_t-2', 'compra_ultima_sem', 'promedio_4s', 'X', 'Y', 'num_deliver_per_week', 'size']
# Features categóricas: ['customer_type', 'brand', 'sub_category', 'segment', 'package']

# %%
train, valid, test = temporal_split(df, train_end="2024-09-30", valid_end="2024-11-30")
print(f"Train: {len(train)}, Valid: {len(valid)}, Test: {len(test)}")

num_cols_outliers = ['X', 'Y', 'size']
iqr_limits = calculate_iqr_limits(train, num_cols_outliers)

train_clean = remove_outliers(train, iqr_limits)
valid_clean = remove_outliers(valid, iqr_limits)
test_clean = remove_outliers(test, iqr_limits)

X_train, y_train = prepare_features(train_clean)
X_valid, y_valid = prepare_features(valid_clean)
X_test, y_test = prepare_features(test_clean)

print(f"Train limpio: {X_train.shape}, Valid limpio: {X_valid.shape}, Test limpio: {X_test.shape}")

numeric_features, categorical_features = get_feature_columns()
print(f"Features numéricas: {numeric_features}")
print(f"Features categóricas: {categorical_features}")
# Out:
# Train: 1190046, Valid: 244112, Test: 183084
# Train limpio: (734721, 13), Valid limpio: (150712, 13), Test limpio: (113034, 13)
# Features numéricas: ['promedio_items_t-1', 'promedio_items_t-2', 'compra_ultima_sem', 'promedio_4s', 'X', 'Y', 'num_deliver_per_week', 'size']
# Features categóricas: ['customer_type', 'brand', 'sub_category', 'segment', 'package']

# %%
default_params = get_default_params()
scaler_type = default_params.pop('scaler')

base_pipeline = create_model_pipeline(
    numeric_features, categorical_features,
    default_params, use_smote=True, scaler_type=scaler_type
)

cv_mean, cv_std = cross_validate_model(base_pipeline, X_train, y_train, n_splits=5)
print(f"Cross-Validation F1 (5-fold): {cv_mean:.4f} (+/- {cv_std*2:.4f})")
# Out:
# Cross-Validation F1 (5-fold): 0.8763 (+/- 0.0011)

# %%
N_TRIALS = 50  # Aumentar para mejor exploración

best_params, best_score = optimize_hyperparameters(
    X_train, y_train, X_valid, y_valid,
    numeric_features, categorical_features,
    n_trials=N_TRIALS, use_smote=True
)

print(f"\nMejor F1 score: {best_score:.4f}")
print(f"Mejores parámetros: {best_params}")
# Out:
# [I 2025-11-19 11:18:40,236] A new study created in memory with name: no-name-285645db-cf2e-48ee-a4c8-9c5f45ce8f0e
#   0%|          | 0/50 [00:00<?, ?it/s]
# [I 2025-11-19 11:19:20,827] Trial 0 finished with value: 0.8609568053043392 and parameters: {'scaler': 'standard', 'num_leaves': 109, 'max_depth': 12, 'learning_rate': 0.12461641319148027, 'n_estimators': 587, 'min_child_samples': 67, 'subsample': 0.7569384653788838, 'colsample_bytree': 0.7776481722045105, 'reg_alpha': 0.8168107773785254, 'reg_lambda': 0.6225710868880756}. Best is trial 0 with value: 0.8609568053043392.
# [I 2025-11-19 11:19:52,820] Trial 1 finished with value: 0.8512877973898345 and parameters: {'scaler': 'minmax', 'num_leaves': 81, 'max_depth': 5, 'learning_rate': 0.019628223011465763, 'n_estimators': 600, 'min_child_samples': 73, 'subsample': 0.569699836939089, 'colsample_bytree': 0.9286275594152973, 'reg_alpha': 0.4344337408995389, 'reg_lambda': 1.9607660536402207}. Best is trial 0 with value: 0.8609568053043392.
# [I 2025-11-19 11:20:29,244] Trial 2 finished with value: 0.8639519866909809 and parameters: {'scaler': 'minmax', 'num_leaves': 126, 'max_depth': 12, 'learning_rate': 0.07972293123356332, 'n_estimators': 504, 'min_child_samples': 34, 'subsample': 0.621587776164024, 'colsample_bytree': 0.8013403962829801, 'reg_alpha': 0.3443160224683772, 'reg_lambda': 0.07589559235645438}. Best is trial 2 with value: 0.8639519866909809.
# [I 2025-11-19 11:20:57,868] Trial 3 finished with value: 0.842344388581181 and parameters: {'scaler': 'standard', 'num_leaves': 143, 'max_depth': 10, 'learning_rate': 0.029685886520273652, 'n_estimators': 170, 'min_child_samples': 37, 'subsample': 0.7185026898008149, 'colsample_bytree': 0.545761371158053, 'reg_alpha': 0.023073431341157136, 'reg_lambda': 0.944649021743087}. Best is trial 2 with value: 0.8639519866909809.
# [I 2025-11-19 11:21:59,941] Trial 4 finished with value: 0.856249102662934 and parameters: {'scaler': 'minmax', 'num_leaves': 189, 'max_depth': 12, 'learning_rate': 0.2510356817427055, 'n_estimators': 720, 'min_child_samples': 35, 'subsample': 0.5625455419488254, 'colsample_bytree': 0.7942324927841569, 'reg_alpha': 1.9084611236655349, 'reg_lambda': 0.33721660147961896}. Best is trial 2 with value: 0.8639519866909809.
# [I 2025-11-19 11:22:52,501] Trial 5 finished with value: 0.8590057099717758 and parameters: {'scaler': 'standard', 'num_leaves': 177, 'max_depth': 10, 'learning_rate': 0.20451482142703611, 'n_estimators': 564, 'min_child_samples': 76, 'subsample': 0.9033502969890899, 'colsample_bytree': 0.8225741292387092, 'reg_alpha': 1.1439489004935373, 'reg_lambda': 0.1809360948675911}. Best is trial 2 with value: 0.8639519866909809.
# [I 2025-11-19 11:23:23,298] Trial 6 finished with value: 0.8499552733699094 and parameters: {'scaler': 'standard', 'num_leaves': 120, 'max_depth': 4, 'learning_rate': 0.08130034387881517, 'n_estimators': 563, 'min_child_samples': 25, 'subsample': 0.5796706877328606, 'colsample_bytree': 0.6746946141173698, 'reg_alpha': 0.2456436060667857, 'reg_lambda': 1.9267496523802692}. Best is trial 2 with value: 0.8639519866909809.
# [I 2025-11-19 11:24:04,853] Trial 7 finished with value: 0.8558636185528645 and parameters: {'scaler': 'standard', 'num_leaves': 45, 'max_depth': 11, 'learning_rate': 0.041449941119457774, 'n_estimators': 678, 'min_child_samples': 89, 'subsample': 0.5801439090198086, 'colsample_bytree': 0.9305733544307422, 'reg_alpha': 1.3027099642675073, 'reg_lambda': 1.2255106768354374}. Best is trial 2 with value: 0.8639519866909809.
# [I 2025-11-19 11:24:30,060] Trial 8 finished with value: 0.8635542085125473 and parameters: {'scaler': 'minmax', 'num_leaves': 44, 'max_depth': 6, 'learning_rate': 0.1829624120708806, 'n_estimators': 381, 'min_child_samples': 51, 'subsample': 0.5920323722373836, 'colsample_bytree': 0.9256273919457143, 'reg_alpha': 0.9696611474343133, 'reg_lambda': 0.6505689336711498}. Best is trial 2 with value: 0.8639519866909809.
# [I 2025-11-19 11:25:47,054] Trial 9 finished with value: 0.8606270116615086 and parameters: {'scaler': 'minmax', 'num_leaves': 129, 'max_depth': 4, 'learning_rate': 0.08057527756301944, 'n_estimators': 426, 'min_child_samples': 19, 'subsample': 0.7673430414159144, 'colsample_bytree': 0.7708660648042034, 'reg_alpha': 0.06335663260204694, 'reg_lambda': 0.16399046750660662}. Best is trial 2 with value: 0.8639519866909809.
# [I 2025-11-19 11:26:18,531] Trial 10 finished with value: 0.8573833398284427 and parameters: {'scaler': 'minmax', 'num_leaves': 85, 'max_depth': 15, 'learning_rate': 0.01088005404204431, 'n_estimators': 263, 'min_child_samples': 51, 'subsample': 0.979583387515321, 'colsample_bytree': 0.6449965698186549, 'reg_alpha': 0.5750624890879674, 'reg_lambda': 1.4065746477944023}. Best is trial 2 with value: 0.8639519866909809.
# [I 2025-11-19 11:26:46,248] Trial 11 finished with value: 0.8636725478037819 and parameters: {'scaler': 'minmax', 'num_leaves': 24, 'max_depth': 7, 'learning_rate': 0.1367057244946164, 'n_estimators': 373, 'min_child_samples': 51, 'subsample': 0.6740256143074624, 'colsample_bytree': 0.9991766681088987, 'reg_alpha': 1.4336159633671217, 'reg_lambda': 0.6150058923844652}. Best is trial 2 with value: 0.8639519866909809.
# [I 2025-11-19 11:27:12,150] Trial 12 finished with value: 0.862726647739366 and parameters: {'scaler': 'minmax', 'num_leaves': 25, 'max_depth': 8, 'learning_rate': 0.09188032925706716, 'n_estimators': 322, 'min_child_samples': 11, 'subsample': 0.6789189318567368, 'colsample_bytree': 0.9805394046933311, 'reg_alpha': 1.5438152718462532, 'reg_lambda': 0.023331644194796608}. Best is trial 2 with value: 0.8639519866909809.
# [I 2025-11-19 11:27:50,301] Trial 13 finished with value: 0.8634629995617388 and parameters: {'scaler': 'minmax', 'num_leaves': 159, 'max_depth': 7, 'learning_rate': 0.051354380704765556, 'n_estimators': 474, 'min_child_samples': 40, 'subsample': 0.6603222546906352, 'colsample_bytree': 0.8436302243516426, 'reg_alpha': 1.5559734290792666, 'reg_lambda': 0.5345379485123191}. Best is trial 2 with value: 0.8639519866909809.
# [I 2025-11-19 11:28:13,903] Trial 14 finished with value: 0.8643299920293307 and parameters: {'scaler': 'minmax', 'num_leaves': 84, 'max_depth': 13, 'learning_rate': 0.13565364064805782, 'n_estimators': 129, 'min_child_samples': 59, 'subsample': 0.8222340817763785, 'colsample_bytree': 0.6852352072507886, 'reg_alpha': 1.8043356591808792, 'reg_lambda': 0.9343249473691263}. Best is trial 14 with value: 0.8643299920293307.
# [I 2025-11-19 11:28:39,211] Trial 15 finished with value: 0.8641329264462204 and parameters: {'scaler': 'minmax', 'num_leaves': 94, 'max_depth': 15, 'learning_rate': 0.1223196169137149, 'n_estimators': 113, 'min_child_samples': 98, 'subsample': 0.8354846256077568, 'colsample_bytree': 0.6730858733062826, 'reg_alpha': 1.9487761993480577, 'reg_lambda': 0.9750378798210689}. Best is trial 14 with value: 0.8643299920293307.
# [I 2025-11-19 11:29:03,837] Trial 16 finished with value: 0.8634506922154618 and parameters: {'scaler': 'minmax', 'num_leaves': 86, 'max_depth': 15, 'learning_rate': 0.13827081103314426, 'n_estimators': 114, 'min_child_samples': 100, 'subsample': 0.8388871242541908, 'colsample_bytree': 0.6692767516315145, 'reg_alpha': 1.951566004494238, 'reg_lambda': 0.9765231934557994}. Best is trial 14 with value: 0.8643299920293307.
# [I 2025-11-19 11:29:29,096] Trial 17 finished with value: 0.8635912338933848 and parameters: {'scaler': 'minmax', 'num_leaves': 64, 'max_depth': 14, 'learning_rate': 0.28514070825245047, 'n_estimators': 226, 'min_child_samples': 88, 'subsample': 0.8301756799967259, 'colsample_bytree': 0.5848398763961359, 'reg_alpha': 1.6712485382768154, 'reg_lambda': 1.5257756005210452}. Best is trial 14 with value: 0.8643299920293307.
# [I 2025-11-19 11:29:51,945] Trial 18 finished with value: 0.8641538404833669 and parameters: {'scaler': 'minmax', 'num_leaves': 101, 'max_depth': 14, 'learning_rate': 0.17255736903616647, 'n_estimators': 111, 'min_child_samples': 63, 'subsample': 0.5044137468943088, 'colsample_bytree': 0.7151738627632808, 'reg_alpha': 1.7742043931338773, 'reg_lambda': 1.1918445302515923}. Best is trial 14 with value: 0.8643299920293307.
# [I 2025-11-19 11:30:18,041] Trial 19 finished with value: 0.864065137896657 and parameters: {'scaler': 'minmax', 'num_leaves': 65, 'max_depth': 14, 'learning_rate': 0.17432859039790843, 'n_estimators': 204, 'min_child_samples': 66, 'subsample': 0.5086648234064013, 'colsample_bytree': 0.724699335784545, 'reg_alpha': 1.7477180992510952, 'reg_lambda': 1.285923693899384}. Best is trial 14 with value: 0.8643299920293307.
# [I 2025-11-19 11:30:49,303] Trial 20 finished with value: 0.8645529640896211 and parameters: {'scaler': 'minmax', 'num_leaves': 105, 'max_depth': 13, 'learning_rate': 0.06076528945763472, 'n_estimators': 287, 'min_child_samples': 63, 'subsample': 0.9026885370729723, 'colsample_bytree': 0.6096122877426546, 'reg_alpha': 1.3421770340552954, 'reg_lambda': 1.6267998894055669}. Best is trial 20 with value: 0.8645529640896211.
# [I 2025-11-19 11:31:20,011] Trial 21 finished with value: 0.863806722773218 and parameters: {'scaler': 'minmax', 'num_leaves': 105, 'max_depth': 13, 'learning_rate': 0.055635841670143106, 'n_estimators': 262, 'min_child_samples': 62, 'subsample': 0.9073786099623924, 'colsample_bytree': 0.6039242513768621, 'reg_alpha': 1.7492705671034965, 'reg_lambda': 1.5484412134547745}. Best is trial 20 with value: 0.8645529640896211.
# [I 2025-11-19 11:31:44,496] Trial 22 finished with value: 0.8565968599062693 and parameters: {'scaler': 'minmax', 'num_leaves': 65, 'max_depth': 13, 'learning_rate': 0.02903632954174727, 'n_estimators': 156, 'min_child_samples': 57, 'subsample': 0.9954593224949457, 'colsample_bytree': 0.7403647893484522, 'reg_alpha': 1.2846326722822357, 'reg_lambda': 1.7368490926881035}. Best is trial 20 with value: 0.8645529640896211.
# [I 2025-11-19 11:32:19,837] Trial 23 finished with value: 0.8639389805320333 and parameters: {'scaler': 'minmax', 'num_leaves': 146, 'max_depth': 13, 'learning_rate': 0.06298166594361705, 'n_estimators': 316, 'min_child_samples': 76, 'subsample': 0.8962910077749388, 'colsample_bytree': 0.710357303809704, 'reg_alpha': 1.4011744767398604, 'reg_lambda': 1.182521026461949}. Best is trial 20 with value: 0.8645529640896211.
# [I 2025-11-19 11:32:46,535] Trial 24 finished with value: 0.8635670343259337 and parameters: {'scaler': 'minmax', 'num_leaves': 99, 'max_depth': 11, 'learning_rate': 0.10280890351419443, 'n_estimators': 144, 'min_child_samples': 59, 'subsample': 0.7895669403250457, 'colsample_bytree': 0.5015986416627548, 'reg_alpha': 1.104128751603619, 'reg_lambda': 0.7746787483435588}. Best is trial 20 with value: 0.8645529640896211.
# [I 2025-11-19 11:33:14,053] Trial 25 finished with value: 0.862774780920899 and parameters: {'scaler': 'minmax', 'num_leaves': 117, 'max_depth': 14, 'learning_rate': 0.2185219700502782, 'n_estimators': 205, 'min_child_samples': 44, 'subsample': 0.8847570234621167, 'colsample_bytree': 0.6093274720061421, 'reg_alpha': 1.7904465354472006, 'reg_lambda': 1.708975011784923}. Best is trial 20 with value: 0.8645529640896211.
# [I 2025-11-19 11:33:50,012] Trial 26 finished with value: 0.8474848872884798 and parameters: {'scaler': 'standard', 'num_leaves': 76, 'max_depth': 9, 'learning_rate': 0.03792599794463476, 'n_estimators': 279, 'min_child_samples': 69, 'subsample': 0.9391446204621243, 'colsample_bytree': 0.572534251278551, 'reg_alpha': 1.5815057254667986, 'reg_lambda': 1.1184857211490697}. Best is trial 20 with value: 0.8645529640896211.
# [I 2025-11-19 11:34:11,889] Trial 27 finished with value: 0.8629784712434012 and parameters: {'scaler': 'minmax', 'num_leaves': 52, 'max_depth': 11, 'learning_rate': 0.16169586456854024, 'n_estimators': 108, 'min_child_samples': 83, 'subsample': 0.5118208443740467, 'colsample_bytree': 0.6400392931848579, 'reg_alpha': 0.7958109263488595, 'reg_lambda': 0.8538067478844209}. Best is trial 20 with value: 0.8645529640896211.
# [I 2025-11-19 11:34:40,342] Trial 28 finished with value: 0.8562329867150822 and parameters: {'scaler': 'minmax', 'num_leaves': 96, 'max_depth': 13, 'learning_rate': 0.019104999039919454, 'n_estimators': 184, 'min_child_samples': 44, 'subsample': 0.7933278009022997, 'colsample_bytree': 0.7032872174408094, 'reg_alpha': 1.4161210584687693, 'reg_lambda': 1.3766625349390034}. Best is trial 20 with value: 0.8645529640896211.
# [I 2025-11-19 11:35:10,103] Trial 29 finished with value: 0.8605230429154442 and parameters: {'scaler': 'standard', 'num_leaves': 110, 'max_depth': 12, 'learning_rate': 0.29944380411266974, 'n_estimators': 320, 'min_child_samples': 65, 'subsample': 0.7153023584931235, 'colsample_bytree': 0.8670088377852205, 'reg_alpha': 0.7872946757156123, 'reg_lambda': 1.1033879770496375}. Best is trial 20 with value: 0.8645529640896211.
# [I 2025-11-19 11:36:07,279] Trial 30 finished with value: 0.8607745636673529 and parameters: {'scaler': 'minmax', 'num_leaves': 153, 'max_depth': 14, 'learning_rate': 0.11941749382679338, 'n_estimators': 784, 'min_child_samples': 71, 'subsample': 0.9438638397567503, 'colsample_bytree': 0.7599904974018628, 'reg_alpha': 1.6416188892616286, 'reg_lambda': 1.581371550311383}. Best is trial 20 with value: 0.8645529640896211.
# [I 2025-11-19 11:36:29,542] Trial 31 finished with value: 0.8639167848798536 and parameters: {'scaler': 'minmax', 'num_leaves': 94, 'max_depth': 15, 'learning_rate': 0.11394630963349239, 'n_estimators': 101, 'min_child_samples': 99, 'subsample': 0.8614289016105976, 'colsample_bytree': 0.6812269748554136, 'reg_alpha': 1.985590103444999, 'reg_lambda': 0.8077387792886568}. Best is trial 20 with value: 0.8645529640896211.
# [I 2025-11-19 11:36:52,421] Trial 32 finished with value: 0.8639725230001878 and parameters: {'scaler': 'minmax', 'num_leaves': 74, 'max_depth': 15, 'learning_rate': 0.15653445842513278, 'n_estimators': 142, 'min_child_samples': 84, 'subsample': 0.8227063023046328, 'colsample_bytree': 0.6421739600510887, 'reg_alpha': 1.8356875064289695, 'reg_lambda': 1.0857600895635449}. Best is trial 20 with value: 0.8645529640896211.
# [I 2025-11-19 11:37:22,667] Trial 33 finished with value: 0.8638575869986597 and parameters: {'scaler': 'minmax', 'num_leaves': 133, 'max_depth': 14, 'learning_rate': 0.07106061938375795, 'n_estimators': 231, 'min_child_samples': 55, 'subsample': 0.7469298815367996, 'colsample_bytree': 0.6233316628955405, 'reg_alpha': 1.8677398899239521, 'reg_lambda': 1.3566009634174925}. Best is trial 20 with value: 0.8645529640896211.
# [I 2025-11-19 11:37:59,989] Trial 34 finished with value: 0.864008976706559 and parameters: {'scaler': 'minmax', 'num_leaves': 110, 'max_depth': 13, 'learning_rate': 0.1000729251444413, 'n_estimators': 170, 'min_child_samples': 79, 'subsample': 0.859173686842468, 'colsample_bytree': 0.5264954963289178, 'reg_alpha': 1.9890940424638535, 'reg_lambda': 0.8922967842180831}. Best is trial 20 with value: 0.8645529640896211.
# [I 2025-11-19 11:38:35,171] Trial 35 finished with value: 0.863675946888698 and parameters: {'scaler': 'minmax', 'num_leaves': 88, 'max_depth': 12, 'learning_rate': 0.2173269144991368, 'n_estimators': 101, 'min_child_samples': 94, 'subsample': 0.7977049575891645, 'colsample_bytree': 0.6918586789641124, 'reg_alpha': 1.6899040650069859, 'reg_lambda': 0.4446745612081683}. Best is trial 20 with value: 0.8645529640896211.
# [I 2025-11-19 11:39:11,287] Trial 36 finished with value: 0.8640867238390615 and parameters: {'scaler': 'minmax', 'num_leaves': 103, 'max_depth': 10, 'learning_rate': 0.12997486068775743, 'n_estimators': 165, 'min_child_samples': 62, 'subsample': 0.9363127327989629, 'colsample_bytree': 0.5656221348514445, 'reg_alpha': 1.4855270516791086, 'reg_lambda': 1.035487204681272}. Best is trial 20 with value: 0.8645529640896211.
# [I 2025-11-19 11:39:46,209] Trial 37 finished with value: 0.8585024618722075 and parameters: {'scaler': 'standard', 'num_leaves': 120, 'max_depth': 15, 'learning_rate': 0.09022529085724264, 'n_estimators': 229, 'min_child_samples': 28, 'subsample': 0.7396674858297705, 'colsample_bytree': 0.7303446634634119, 'reg_alpha': 1.2811276305247792, 'reg_lambda': 0.7279739913783505}. Best is trial 20 with value: 0.8645529640896211.
# [I 2025-11-19 11:40:21,179] Trial 38 finished with value: 0.8623728018364064 and parameters: {'scaler': 'minmax', 'num_leaves': 137, 'max_depth': 11, 'learning_rate': 0.24112377006367477, 'n_estimators': 363, 'min_child_samples': 72, 'subsample': 0.8657010926391089, 'colsample_bytree': 0.6593747890552735, 'reg_alpha': 1.8647464801165219, 'reg_lambda': 1.8559808833817717}. Best is trial 20 with value: 0.8645529640896211.
# [I 2025-11-19 11:40:46,841] Trial 39 finished with value: 0.8441807506389234 and parameters: {'scaler': 'standard', 'num_leaves': 76, 'max_depth': 12, 'learning_rate': 0.045726627893322616, 'n_estimators': 135, 'min_child_samples': 48, 'subsample': 0.7738247761364432, 'colsample_bytree': 0.7981124250582585, 'reg_alpha': 1.1138442056603604, 'reg_lambda': 0.9508141114461247}. Best is trial 20 with value: 0.8645529640896211.
# [I 2025-11-19 11:41:26,444] Trial 40 finished with value: 0.8642151003872148 and parameters: {'scaler': 'minmax', 'num_leaves': 113, 'max_depth': 9, 'learning_rate': 0.07106896090029041, 'n_estimators': 429, 'min_child_samples': 76, 'subsample': 0.6326946352276216, 'colsample_bytree': 0.5425607164564422, 'reg_alpha': 0.9824308652160754, 'reg_lambda': 1.2221557922283173}. Best is trial 20 with value: 0.8645529640896211.
# [I 2025-11-19 11:41:55,275] Trial 41 finished with value: 0.8530973566934864 and parameters: {'scaler': 'minmax', 'num_leaves': 113, 'max_depth': 3, 'learning_rate': 0.0684914370272203, 'n_estimators': 429, 'min_child_samples': 79, 'subsample': 0.5351779464953221, 'colsample_bytree': 0.5422630107468834, 'reg_alpha': 0.9365134753797744, 'reg_lambda': 1.1973269498959473}. Best is trial 20 with value: 0.8645529640896211.
# [I 2025-11-19 11:42:30,012] Trial 42 finished with value: 0.8639060487971939 and parameters: {'scaler': 'minmax', 'num_leaves': 124, 'max_depth': 14, 'learning_rate': 0.035862688224999474, 'n_estimators': 282, 'min_child_samples': 93, 'subsample': 0.6453372191614545, 'colsample_bytree': 0.5957243908556812, 'reg_alpha': 1.197197032546563, 'reg_lambda': 1.4823301056720986}. Best is trial 20 with value: 0.8645529640896211.
# [I 2025-11-19 11:43:16,793] Trial 43 finished with value: 0.8639873704024 and parameters: {'scaler': 'minmax', 'num_leaves': 90, 'max_depth': 9, 'learning_rate': 0.06080521328627821, 'n_estimators': 652, 'min_child_samples': 60, 'subsample': 0.6027883323666955, 'colsample_bytree': 0.6261344147849857, 'reg_alpha': 0.7136370354890909, 'reg_lambda': 1.2705511129689466}. Best is trial 20 with value: 0.8645529640896211.
# [I 2025-11-19 11:43:52,860] Trial 44 finished with value: 0.8637509252180331 and parameters: {'scaler': 'minmax', 'num_leaves': 102, 'max_depth': 6, 'learning_rate': 0.07892158549691027, 'n_estimators': 486, 'min_child_samples': 69, 'subsample': 0.5465672001301878, 'colsample_bytree': 0.5604278373061916, 'reg_alpha': 0.8964178540631773, 'reg_lambda': 1.671258830961309}. Best is trial 20 with value: 0.8645529640896211.
# [I 2025-11-19 11:44:39,445] Trial 45 finished with value: 0.8632535033341024 and parameters: {'scaler': 'minmax', 'num_leaves': 95, 'max_depth': 12, 'learning_rate': 0.15529909885563448, 'n_estimators': 529, 'min_child_samples': 55, 'subsample': 0.6235978581502545, 'colsample_bytree': 0.5055005530097844, 'reg_alpha': 1.0079237772256024, 'reg_lambda': 1.0121805904832906}. Best is trial 20 with value: 0.8645529640896211.
# [I 2025-11-19 11:45:06,174] Trial 46 finished with value: 0.8632248430716514 and parameters: {'scaler': 'minmax', 'num_leaves': 173, 'max_depth': 9, 'learning_rate': 0.1942341417724199, 'n_estimators': 193, 'min_child_samples': 65, 'subsample': 0.8058990358650289, 'colsample_bytree': 0.6644047229466071, 'reg_alpha': 0.6766146108316097, 'reg_lambda': 0.7051152056194141}. Best is trial 20 with value: 0.8645529640896211.
# [I 2025-11-19 11:45:41,106] Trial 47 finished with value: 0.8608335718310635 and parameters: {'scaler': 'standard', 'num_leaves': 82, 'max_depth': 13, 'learning_rate': 0.11672211557726447, 'n_estimators': 432, 'min_child_samples': 75, 'subsample': 0.6992458013235812, 'colsample_bytree': 0.7698765195532923, 'reg_alpha': 1.6057806792938025, 'reg_lambda': 1.8597424289651001}. Best is trial 20 with value: 0.8645529640896211.
# [I 2025-11-19 11:46:13,004] Trial 48 finished with value: 0.8638156577800223 and parameters: {'scaler': 'minmax', 'num_leaves': 57, 'max_depth': 15, 'learning_rate': 0.14535118429783636, 'n_estimators': 405, 'min_child_samples': 85, 'subsample': 0.9203125957014728, 'colsample_bytree': 0.7130246003126297, 'reg_alpha': 1.9285958698005854, 'reg_lambda': 0.8983206224832834}. Best is trial 20 with value: 0.8645529640896211.
# [I 2025-11-19 11:46:40,515] Trial 49 finished with value: 0.8621156498730759 and parameters: {'scaler': 'minmax', 'num_leaves': 130, 'max_depth': 5, 'learning_rate': 0.09260304644214247, 'n_estimators': 357, 'min_child_samples': 52, 'subsample': 0.8392935943325004, 'colsample_bytree': 0.5471123847412287, 'reg_alpha': 1.7459572718398717, 'reg_lambda': 1.4496606013853872}. Best is trial 20 with value: 0.8645529640896211.
#
# Mejor F1 score: 0.8646
# Mejores parámetros: {'scaler': 'minmax', 'num_leaves': 105, 'max_depth': 13, 'learning_rate': 0.06076528945763472, 'n_estimators': 287, 'min_child_samples': 63, 'subsample': 0.9026885370729723, 'colsample_bytree': 0.6096122877426546, 'reg_alpha': 1.3421770340552954, 'reg_lambda': 1.6267998894055669}

# %%
final_model = train_final_model(
    X_train, y_train,
    numeric_features, categorical_features,
    best_params.copy(), use_smote=True
)

optimal_threshold, threshold_f1 = find_optimal_threshold(final_model, X_valid, y_valid)
print(f"Threshold óptimo: {optimal_threshold:.2f}, F1: {threshold_f1:.4f}")
# Out:
# Threshold óptimo: 0.42, F1: 0.5119

# %%
valid_metrics = evaluate_model(final_model, X_valid, y_valid)
print("=== Métricas en Validación ===")
print(f"F1 Weighted: {valid_metrics['f1_weighted']:.4f}")
print(f"F1 Clase 1: {valid_metrics['f1_class1']:.4f}")
print(f"ROC-AUC: {valid_metrics['roc_auc']:.4f}")
print(f"PR-AUC: {valid_metrics['pr_auc']:.4f}")

test_metrics = evaluate_model(final_model, X_test, y_test)
print("\n=== Métricas en Test ===")
print(f"F1 Weighted: {test_metrics['f1_weighted']:.4f}")
print(f"F1 Clase 1: {test_metrics['f1_class1']:.4f}")
print(f"ROC-AUC: {test_metrics['roc_auc']:.4f}")
print(f"PR-AUC: {test_metrics['pr_auc']:.4f}")
# Out:
# === Métricas en Validación ===
# F1 Weighted: 0.8646
# F1 Clase 1: 0.4933
# ROC-AUC: 0.7753
# PR-AUC: 0.4859
#
# === Métricas en Test ===
# F1 Weighted: 0.8519
# F1 Clase 1: 0.4797
# ROC-AUC: 0.7604
# PR-AUC: 0.4475

# %%
save_model(final_model, 'models/modelo_final.pkl')
print("Modelo guardado en models/modelo_final.pkl")

next_week = get_next_week_date(df)
print(f"Generando predicciones para: {next_week.strftime('%Y-%m-%d')}")

prediction_data = prepare_prediction_data(df, clientes, productos)
predictions = generate_predictions(final_model, prediction_data, threshold=optimal_threshold)

summary = summarize_predictions(predictions)
print(f"\nResumen de predicciones:")
print(f"  Total: {summary['total_predictions']}")
print(f"  Positivas: {summary['positive_predictions']}")
print(f"  Probabilidad promedio: {summary['avg_probability']:.4f}")

save_predictions(predictions, 'data/predicciones_2025_semana1.parquet')
print("\nPredicciones guardadas en data/predicciones_2025_semana1.parquet")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 save_model(final_model, 'models/modelo_final.pkl')
#       2 print("Modelo guardado en models/modelo_final.pkl")
#       4 next_week = get_next_week_date(df)
#
# File c:\Users\crist\Desktop\MDS7202-labs\proyecto_lab\entrega2\src\model.py:175, in save_model(model, path)
#     173 def save_model(model, path: str):
#     174     """Guarda el modelo en disco."""
# --> 175     joblib.dump(model, path)
#
# File c:\Users\crist\AppData\Local\Programs\Python\Python312\Lib\site-packages\joblib\numpy_pickle.py:599, in dump(value, filename, compress, protocol)
#     597         NumpyPickler(f, protocol=protocol).dump(value)
#     598 elif is_filename:
# --> 599     with open(filename, "wb") as f:
#     600         NumpyPickler(f, protocol=protocol).dump(value)
#     601 else:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'models/modelo_final.pkl'

# %%
predictions.head(10)
